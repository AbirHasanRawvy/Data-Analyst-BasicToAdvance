# %% [markdown]
# # ***Pandas Librery Related!***

# %%
import pandas as pd

# %% [markdown]
# # **Series Data**

# %%
age = pd.Series([10,20,30,40,50])
print(age)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %% [markdown]
# # **Data Frame**

# %%
data=pd.DataFrame(age)
print(data)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50
