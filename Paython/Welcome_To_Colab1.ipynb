# %%
import pandas as pd

# %%
age = [10, 20, 30, 40, 50]

# %%
data = pd.DataFrame(age);
print(data)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %% [markdown]
# # **Data Frame**

# %%
data1 = {
    'Product': ['Laptop', 'Mobile', 'Mouse'],
    'Price': [1000, 2000, 300]
}
print(data1)
print('=================================================')
pd.DataFrame(data1)
# Out:
# {'Product': ['Laptop', 'Mobile', 'Mouse'], 'Price': [1000, 2000, 300]}
# ...
#   Product  Price
# 0  Laptop   1000
# 1  Mobile   2000
# 2   Mouse    300

# %% [markdown]
# # **Data Frame**

# %%
df = pd.read_csv('/DataSheet.csv')

# %% [markdown]
# # **Show total data**

# %%
df
# Out:
#     OrderID  CustomerID CustomerName        City  ProductID ProductName  \
# 0         1         101        Rahim       Dhaka        201      Laptop
# 1         2         102        Karim      Khulna        202       Mouse
# 2         3         103        Jamil       Dhaka        203    Keyboard
# 3         4         104        Salma  Chattogram        204     Printer
# 4         5         105        Nadia    Rajshahi        205     Monitor
# 5         6         106       Shohan      Shylet        206      Router
# 6         7         107        Tania       Dhaka        207         SSD
# 7         8         108        Rifat      Khulna        208         HDD
# 8         9         109        Imran     Barisal        209         UPS
# 9        10         110         Nila     Rangpur        210     Scanner
# 10       11         101        Rahim       Dhaka        201      Laptop
# 11       12         102        Karim      Khulna        202       Mouse
# ...

# %% [markdown]
# # **First 5 data**

# %%
df.head()
# Out:
#    OrderID  CustomerID CustomerName        City  ProductID ProductName  \
# 0        1         101        Rahim       Dhaka        201      Laptop
# 1        2         102        Karim      Khulna        202       Mouse
# 2        3         103        Jamil       Dhaka        203    Keyboard
# 3        4         104        Salma  Chattogram        204     Printer
# 4        5         105        Nadia    Rajshahi        205     Monitor
#
#       Category  OrderDate  Quantity  UnitPrice   Amout
# 0  Electonicks   3/1/2025         3      50000  150000
# 1  Electonicks   5/1/2025         3       1000    3000
# 2  Electonicks   7/1/2025         2       1500    3000
# 3  Electonicks   9/1/2025         3      15000   45000
# 4  Electonicks  11/1/2025         3      12000   36000

# %% [markdown]
# # **Last 5 data**

# %%
df.tail()
# Out:
#     OrderID  CustomerID CustomerName     City  ProductID ProductName  \
# 55       56         106       Shohan   Shylet        206      Router
# 56       57         107        Tania    Dhaka        207         SSD
# 57       58         108        Rifat   Khulna        208         HDD
# 58       59         109        Imran  Barisal        209         UPS
# 59       60         110         Nila  Rangpur        210     Scanner
#
#        Category  OrderDate  Quantity  UnitPrice  Amout
# 55      Network  23/4/2025         4       3000  12000
# 56      Storage  25/4/2025         1       6000   6000
# 57      Storage  27/4/2025         5       5000  25000
# 58        Power  29/4/2025         5       8000  40000
# 59  Electonicks   1/5/2025         4      10000  40000

# %% [markdown]
# # **Find out total row and coloum**

# %%
df.shape
# Out:
# (60, 11)

# %% [markdown]
# # **Data set descriotion**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       60 non-null     int64
#  1   CustomerID    60 non-null     int64
#  2   CustomerName  60 non-null     object
#  3   City          60 non-null     object
#  4   ProductID     60 non-null     int64
#  5   ProductName   60 non-null     object
#  6   Category      60 non-null     object
#  7   OrderDate     60 non-null     object
#  8   Quantity      60 non-null     int64
#  9   UnitPrice     60 non-null     int64
#  10  Amout         60 non-null     int64
# dtypes: int64(6), object(5)
# memory usage: 5.3+ KB

# %% [markdown]
# # **Data set statistics**

# %%
df.describe()
# Out:
#          OrderID  CustomerID  ProductID   Quantity     UnitPrice  \
# count  60.000000    60.00000   60.00000  60.000000     60.000000
# mean   30.500000   105.50000  205.50000   3.200000  11150.000000
# std    17.464249     2.89652    2.89652   1.423769  13764.453113
# min     1.000000   101.00000  201.00000   1.000000   1000.000000
# 25%    15.750000   103.00000  203.00000   2.000000   3000.000000
# 50%    30.500000   105.50000  205.50000   3.000000   7000.000000
# 75%    45.250000   108.00000  208.00000   4.000000  12000.000000
# max    60.000000   110.00000  210.00000   5.000000  50000.000000
#
#                Amout
# count      60.000000
# mean    35608.333333
# std     47711.801801
# min      1000.000000
# 25%      6000.000000
# 50%     19000.000000
# 75%     48500.000000
# max    250000.000000

# %% [markdown]
# # **Check the null value if have!**

# %%
df.isnull().sum()
# Out:
# OrderID         0
# CustomerID      0
# CustomerName    0
# City            0
# ProductID       0
# ProductName     0
# Category        0
# OrderDate       0
# Quantity        0
# UnitPrice       0
# Amout           0
# dtype: int64

# %% [markdown]
# # **See all the column**

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerID', 'CustomerName', 'City', 'ProductID',
#        'ProductName', 'Category', 'OrderDate', 'Quantity', 'UnitPrice',
#        'Amout'],
#       dtype='object')

# %% [markdown]
# # **Average ravenue/Mean**

# %%
df['Amout'].mean()
# Out:
# np.float64(35608.333333333336)
